# %%
pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/df/b2/dfdc17f701f7b587f6c89c2b9b6b5978c87a8a785555efc810b064c875de/redis-5.0.0-py3-none-any.whl.metadata
#   Downloading redis-5.0.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\users\mohds\appdata\local\programs\python\python311\lib\site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\mohds\appdata\local\programs\python\python311\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\mohds\appdata\local\programs\python\python311\lib\site-packages (from spotipy) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mohds\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25.0->spotipy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mohds\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mohds\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25.0->spotipy) (2023.7.22)
# Downloading redis-5.0.0-py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.1 kB ? eta -:--:--
#    ------------------------------- -------- 194.6/250.1 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 250.1/250.1 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.0 spotipy-2.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager=SpotifyClientCredentials(client_id= 'f87b4353b8104eb1b4614031a13f0d21', client_secret='5743e5aea922432895e40c6fe8d21fe3')

# %%
sp= spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF'

# %%
 playlist_URI=playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Paint The Town Red'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-08-04'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/54dZypaXHAIDzBe9ujAZ63'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date= row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id': album_id,'name': album_name, 'release_date': album_release_date, 'total_tracks': album_total_tracks, 'url': album_url}
    print (album_element)
    album_list.append(album_element)
# Out:
# {'album_id': '54dZypaXHAIDzBe9ujAZ63', 'name': 'Paint The Town Red', 'release_date': '2023-08-04', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/54dZypaXHAIDzBe9ujAZ63'}
# {'album_id': '53985D8g3JcGBoULSOYYKX', 'name': 'Seven (feat. Latto)', 'release_date': '2023-07-14', 'total_tracks': 3, 'url': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '1NAmidJlEaVgA3MpcPFYGq', 'name': 'Lover', 'release_date': '2019-08-23', 'total_tracks': 18, 'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '7ixOAT89NSsgUITYc5ByB5', 'name': 'Layover', 'release_date': '2023-09-08', 'total_tracks': 6, 'url': 'https://open.spotify.com/album/7ixOAT89NSsgUITYc5ByB5'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '3puAvurwvtvi1rodndIPW8', 'name': 'LA VIDA ES UNA', 'release_date': '2023-03-23', 'total_tracks': 23, 'url': 'https://open.spotify.com/album/3puAvurwvtvi1rodndIPW8'}
# {'album_id': '0FqAaUEyKCyUNFE1uQPZ7i', 'name': 'MAÑANA SERÁ BONITO (BICHOTA SEASON)', 'release_date': '2023-08-10', 'total_tracks': 9, 'url': 'https://open.spotify.com/album/0FqAaUEyKCyUNFE1uQPZ7i'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '5cH7FqB7JD5q1tJXJ7FHYu', 'name': 'Dance The Night (From Barbie The Album)', 'release_date': '2023-05-25', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/5cH7FqB7JD5q1tJXJ7FHYu'}
# {'album_id': '07kam1Dks7GIucbSelfvyX', 'name': 'Columbia', 'release_date': '2023-07-07', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/07kam1Dks7GIucbSelfvyX'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '1ZBDI1LqnuAKdrePUF2D5m', 'name': 'Layover', 'release_date': '2023-08-11', 'total_tracks': 2, 'url': 'https://open.spotify.com/album/1ZBDI1LqnuAKdrePUF2D5m'}
# {'album_id': '3AafSrFIbJPH6BJHiJm1Cd', 'name': 'What Was I Made For? [From The Motion Picture "Barbie"]', 'release_date': '2023-07-13', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/3AafSrFIbJPH6BJHiJm1Cd'}
# {'album_id': '5qmZefgh78fN3jsyPPlvuw', 'name': 'a Gift & a Curse', 'release_date': '2023-06-16', 'total_tracks': 15, 'url': 'https://open.spotify.com/album/5qmZefgh78fN3jsyPPlvuw'}
# {'album_id': '1xJHno7SmdVtZAtXbdbDZp', 'name': 'GUTS', 'release_date': '2023-09-08', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}
# {'album_id': '1ZBDI1LqnuAKdrePUF2D5m', 'name': 'Layover', 'release_date': '2023-08-11', 'total_tracks': 2, 'url': 'https://open.spotify.com/album/1ZBDI1LqnuAKdrePUF2D5m'}
# {'album_id': '5l0QlaI3wdZpE7ggoO5Rwg', 'name': 'Sprinter', 'release_date': '2023-06-01', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/5l0QlaI3wdZpE7ggoO5Rwg'}
# {'album_id': '6NcI39WPu4kY6Tul11nhSv', 'name': 'Daylight', 'release_date': '2023-04-14', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/6NcI39WPu4kY6Tul11nhSv'}
# {'album_id': '6PbnGueEO6LGodPfvNldYf', 'name': 'Zach Bryan', 'release_date': '2023-08-25', 'total_tracks': 16, 'url': 'https://open.spotify.com/album/6PbnGueEO6LGodPfvNldYf'}
# {'album_id': '5r36AJ6VOJtp00oxSkBZ5h', 'name': "Harry's House", 'release_date': '2022-05-20', 'total_tracks': 13, 'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'}
# {'album_id': '4jox3ip1I39DFC2B7R5qLH', 'name': 'GÉNESIS', 'release_date': '2023-06-29', 'total_tracks': 17, 'url': 'https://open.spotify.com/album/4jox3ip1I39DFC2B7R5qLH'}
# {'album_id': '0HiZ8fNXwJOQcrf5iflrdz', 'name': 'Endless Summer Vacation', 'release_date': '2023-03-10', 'total_tracks': 13, 'url': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'}
# {'album_id': '5MU0RmBSpoSxOPYBfcobDc', 'name': 'Prada', 'release_date': '2023-08-11', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/5MU0RmBSpoSxOPYBfcobDc'}
# {'album_id': '1nrVofqDRs7cpWXJ49qTnP', 'name': 'SOS', 'release_date': '2022-12-08', 'total_tracks': 23, 'url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'}
# {'album_id': '4x6cjOcVz44aiLSOHCLKPd', 'name': 'Que Onda', 'release_date': '2023-08-30', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/4x6cjOcVz44aiLSOHCLKPd'}
# {'album_id': '78bpIziExqiI9qztvNFlQu', 'name': 'AM', 'release_date': '2013-09-09', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'}
# {'album_id': '4jtQUtS4ABgER3DnGfKJCv', 'name': 'Classy 101', 'release_date': '2023-03-31', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/4jtQUtS4ABgER3DnGfKJCv'}
# {'album_id': '5V729UqvhwNOcMejx0m55I', 'name': "NewJeans 'Super Shy'", 'release_date': '2023-07-07', 'total_tracks': 2, 'url': 'https://open.spotify.com/album/5V729UqvhwNOcMejx0m55I'}
# {'album_id': '2LVDNOUUy2g8517ZEtQIcK', 'name': '(It Goes Like) Nanana [Edit]', 'release_date': '2023-06-15', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/2LVDNOUUy2g8517ZEtQIcK'}
# {'album_id': '5gCcb5fsSb6w5K8SyJrgtB', 'name': 'WHERE SHE GOES', 'release_date': '2023-05-18', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/5gCcb5fsSb6w5K8SyJrgtB'}
# {'album_id': '5CM66hwjlbZ06LhONWXOAs', 'name': 'Barbie World (with Aqua) [From Barbie The Album]', 'release_date': '2023-06-23', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/5CM66hwjlbZ06LhONWXOAs'}
# {'album_id': '6aBVGuOUEuX18rHxyDWbti', 'name': 'La Bebe (Remix)', 'release_date': '2023-03-17', 'total_tracks': 2, 'url': 'https://open.spotify.com/album/6aBVGuOUEuX18rHxyDWbti'}
# {'album_id': '52PtAAvfi8ZGTRK5c700y4', 'name': 'Colmillo De Leche', 'release_date': '2023-05-19', 'total_tracks': 18, 'url': 'https://open.spotify.com/album/52PtAAvfi8ZGTRK5c700y4'}
# {'album_id': '0FqAaUEyKCyUNFE1uQPZ7i', 'name': 'MAÑANA SERÁ BONITO (BICHOTA SEASON)', 'release_date': '2023-08-10', 'total_tracks': 9, 'url': 'https://open.spotify.com/album/0FqAaUEyKCyUNFE1uQPZ7i'}
# {'album_id': '5O0zUvdnJr0RbWzLFneN2i', 'name': 'Popular (Music from the HBO Original Series)', 'release_date': '2023-06-02', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/5O0zUvdnJr0RbWzLFneN2i'}
# {'album_id': '42D6fdFJ4SLnh4jXZJrsNa', 'name': 'Holanda', 'release_date': '2023-07-28', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/42D6fdFJ4SLnh4jXZJrsNa'}
# {'album_id': '7ixOAT89NSsgUITYc5ByB5', 'name': 'Layover', 'release_date': '2023-09-08', 'total_tracks': 6, 'url': 'https://open.spotify.com/album/7ixOAT89NSsgUITYc5ByB5'}
# {'album_id': '18NOKLkZETa4sWwLMIm0UZ', 'name': 'UTOPIA', 'release_date': '2023-07-28', 'total_tracks': 19, 'url': 'https://open.spotify.com/album/18NOKLkZETa4sWwLMIm0UZ'}
# {'album_id': '7ixOAT89NSsgUITYc5ByB5', 'name': 'Layover', 'release_date': '2023-09-08', 'total_tracks': 6, 'url': 'https://open.spotify.com/album/7ixOAT89NSsgUITYc5ByB5'}
# {'album_id': '2QJmrSgbdM35R67eoGQo4j', 'name': '1989', 'release_date': '2014-10-27', 'total_tracks': 13, 'url': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'}
# {'album_id': '2QJmrSgbdM35R67eoGQo4j', 'name': '1989', 'release_date': '2014-10-27', 'total_tracks': 13, 'url': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'}
# {'album_id': '18ogtNq9F7DmMkNYO6Xb4k', 'name': 'Strangers', 'release_date': '2023-09-01', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/18ogtNq9F7DmMkNYO6Xb4k'}

# %%
data ['items'][0]['track']['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#  'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#  'id': '5cj0lLjcoR7YOSnhnX0Po5',
#  'name': 'Doja Cat',
#  'type': 'artist',
#  'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
         if key =='track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
            
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5cj0lLjcoR7YOSnhnX0Po5',
#   'artist_name': 'Doja Cat',
#   'external_url': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5'},
#  {'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#   'artist_name': 'Jung Kook',
#   'external_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'},
#  {'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'artist_name': 'Latto',
#   'external_url': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '3JsHnjpbhX4SnySpvpa9DK',
#   'artist_name': 'V',
#   'external_url': 'https://api.spotify.com/v1/artists/3JsHnjpbhX4SnySpvpa9DK'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '7iK8PXO48WeuP03g8YR51W',
#   'artist_name': 'Myke Towers',
#   'external_url': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa',
#   'external_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '52iwsT98xCoGgiGntTiR7K',
#   'artist_name': 'Quevedo',
#   'external_url': 'https://api.spotify.com/v1/artists/52iwsT98xCoGgiGntTiR7K'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '3JsHnjpbhX4SnySpvpa9DK',
#   'artist_name': 'V',
#   'external_url': 'https://api.spotify.com/v1/artists/3JsHnjpbhX4SnySpvpa9DK'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '2hlmm7s2ICUX0LVIhVFlZQ',
#   'artist_name': 'Gunna',
#   'external_url': 'https://api.spotify.com/v1/artists/2hlmm7s2ICUX0LVIhVFlZQ'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '3JsHnjpbhX4SnySpvpa9DK',
#   'artist_name': 'V',
#   'external_url': 'https://api.spotify.com/v1/artists/3JsHnjpbhX4SnySpvpa9DK'},
#  {'artist_id': '6Ip8FS7vWT1uKkJSweANQK',
#   'artist_name': 'Dave',
#   'external_url': 'https://api.spotify.com/v1/artists/6Ip8FS7vWT1uKkJSweANQK'},
#  {'artist_id': '5H4yInM5zmHqpKIoMNAx4r',
#   'artist_name': 'Central Cee',
#   'external_url': 'https://api.spotify.com/v1/artists/5H4yInM5zmHqpKIoMNAx4r'},
#  {'artist_id': '33NVpKoXjItPwUJTMZIOiY',
#   'artist_name': 'David Kushner',
#   'external_url': 'https://api.spotify.com/v1/artists/33NVpKoXjItPwUJTMZIOiY'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'external_url': 'https://api.spotify.com/v1/artists/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_id': '70kkdajctXSbqSMJbQO424',
#   'artist_name': 'Kacey Musgraves',
#   'external_url': 'https://api.spotify.com/v1/artists/70kkdajctXSbqSMJbQO424'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '6Sbl0NT50roqWvy746MfVf',
#   'artist_name': 'Gabito Ballesteros',
#   'external_url': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf'},
#  {'artist_id': '7Gi6gjaWy3DxyilpF1a8Is',
#   'artist_name': 'Junior H',
#   'external_url': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is'},
#  {'artist_id': '5YGY8feqx7naU7z4HrwZM6',
#   'artist_name': 'Miley Cyrus',
#   'external_url': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6'},
#  {'artist_id': '5wCmhq5J2hPwL2r0eKurxn',
#   'artist_name': 'cassö',
#   'external_url': 'https://api.spotify.com/v1/artists/5wCmhq5J2hPwL2r0eKurxn'},
#  {'artist_id': '5KKpBU5eC2tJDzf0wmlRp2',
#   'artist_name': 'RAYE',
#   'external_url': 'https://api.spotify.com/v1/artists/5KKpBU5eC2tJDzf0wmlRp2'},
#  {'artist_id': '5VadK1havLhK1OpKYsXv9y',
#   'artist_name': 'D-Block Europe',
#   'external_url': 'https://api.spotify.com/v1/artists/5VadK1havLhK1OpKYsXv9y'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '6dLuQ5qXxIuWc5urxfIiZR',
#   'artist_name': 'Calle 24',
#   'external_url': 'https://api.spotify.com/v1/artists/6dLuQ5qXxIuWc5urxfIiZR'},
#  {'artist_id': '2rmkQLzj0k4nZdQehOUByO',
#   'artist_name': 'Chino Pacas',
#   'external_url': 'https://api.spotify.com/v1/artists/2rmkQLzj0k4nZdQehOUByO'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'external_url': 'https://api.spotify.com/v1/artists/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'external_url': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'artist_name': 'Feid',
#   'external_url': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_id': '3qsKSpcV3ncke3hw52JSMB',
#   'artist_name': 'Young Miko',
#   'external_url': 'https://api.spotify.com/v1/artists/3qsKSpcV3ncke3hw52JSMB'},
#  {'artist_id': '6HvZYsbFfjnjFrWF950C9d',
#   'artist_name': 'NewJeans',
#   'external_url': 'https://api.spotify.com/v1/artists/6HvZYsbFfjnjFrWF950C9d'},
#  {'artist_id': '2mLA48B366zkELXYx7hcDN',
#   'artist_name': 'Peggy Gou',
#   'external_url': 'https://api.spotify.com/v1/artists/2mLA48B366zkELXYx7hcDN'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '0hCNtLu0JehylgoiP8L4Gh',
#   'artist_name': 'Nicki Minaj',
#   'external_url': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh'},
#  {'artist_id': '3LZZPxNDGDFVSIPqf4JuEf',
#   'artist_name': 'Ice Spice',
#   'external_url': 'https://api.spotify.com/v1/artists/3LZZPxNDGDFVSIPqf4JuEf'},
#  {'artist_id': '6kBjAFKyd0he7LiA5GQ3Gz',
#   'artist_name': 'Aqua',
#   'external_url': 'https://api.spotify.com/v1/artists/6kBjAFKyd0he7LiA5GQ3Gz'},
#  {'artist_id': '1NNRWkhwmcXRimFYSBpB1y',
#   'artist_name': 'Yng Lvcas',
#   'external_url': 'https://api.spotify.com/v1/artists/1NNRWkhwmcXRimFYSBpB1y'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '66ihevNkSYNzRAl44dx6jJ',
#   'artist_name': 'Carin Leon',
#   'external_url': 'https://api.spotify.com/v1/artists/66ihevNkSYNzRAl44dx6jJ'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '6tbjWDEIzxoDsBA1FuhfPW',
#   'artist_name': 'Madonna',
#   'external_url': 'https://api.spotify.com/v1/artists/6tbjWDEIzxoDsBA1FuhfPW'},
#  {'artist_id': '6nVcHLIgY5pE2YCl8ubca1',
#   'artist_name': 'Jhayco',
#   'external_url': 'https://api.spotify.com/v1/artists/6nVcHLIgY5pE2YCl8ubca1'},
#  {'artist_id': '3JsHnjpbhX4SnySpvpa9DK',
#   'artist_name': 'V',
#   'external_url': 'https://api.spotify.com/v1/artists/3JsHnjpbhX4SnySpvpa9DK'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '3JsHnjpbhX4SnySpvpa9DK',
#   'artist_name': 'V',
#   'external_url': 'https://api.spotify.com/v1/artists/3JsHnjpbhX4SnySpvpa9DK'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '7uMDnSZyUYNBPLhPMNuaM2',
#   'artist_name': 'Kenya Grace',
#   'external_url': 'https://api.spotify.com/v1/artists/7uMDnSZyUYNBPLhPMNuaM2'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2IGMVunIBsBLtEQyoI1Mu7',
#   'song_name': 'Paint The Town Red',
#   'duration_ms': 231750,
#   'url': 'https://open.spotify.com/track/2IGMVunIBsBLtEQyoI1Mu7',
#   'popularity': 98,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '54dZypaXHAIDzBe9ujAZ63',
#   'artist_id': '5cj0lLjcoR7YOSnhnX0Po5'},
#  {'song_id': '7x9aauaA9cu6tyfpHnqDLo',
#   'song_name': 'Seven (feat. Latto) (Explicit Ver.)',
#   'duration_ms': 184400,
#   'url': 'https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo',
#   'popularity': 99,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '53985D8g3JcGBoULSOYYKX',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc'},
#  {'song_id': '1kuGVB7EU95pJObxwvfwKS',
#   'song_name': 'vampire',
#   'duration_ms': 219724,
#   'url': 'https://open.spotify.com/track/1kuGVB7EU95pJObxwvfwKS',
#   'popularity': 50,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '3IX0yuEVvDbnqUwMBB3ouC',
#   'song_name': 'bad idea right?',
#   'duration_ms': 184783,
#   'url': 'https://open.spotify.com/track/3IX0yuEVvDbnqUwMBB3ouC',
#   'popularity': 52,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '34sOdxWu9FljH84UXdRwu1',
#   'song_name': 'all-american bitch',
#   'duration_ms': 165833,
#   'url': 'https://open.spotify.com/track/34sOdxWu9FljH84UXdRwu1',
#   'popularity': 58,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '2gyxAWHebV7xPYVxqoi86f',
#   'song_name': 'get him back!',
#   'duration_ms': 211141,
#   'url': 'https://open.spotify.com/track/2gyxAWHebV7xPYVxqoi86f',
#   'popularity': 56,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_name': 'Cruel Summer',
#   'duration_ms': 178426,
#   'url': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr',
#   'popularity': 100,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '6QT6j7rKt7Vk3IuV2AUO9W',
#   'song_name': 'lacy',
#   'duration_ms': 177212,
#   'url': 'https://open.spotify.com/track/6QT6j7rKt7Vk3IuV2AUO9W',
#   'popularity': 56,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '5sp71CUt0jXRNqHblPGp7b',
#   'song_name': 'ballad of a homeschooled girl',
#   'duration_ms': 203369,
#   'url': 'https://open.spotify.com/track/5sp71CUt0jXRNqHblPGp7b',
#   'popularity': 56,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '5CscrLqFBgPfZR8fGtikov',
#   'song_name': 'making the bed',
#   'duration_ms': 198866,
#   'url': 'https://open.spotify.com/track/5CscrLqFBgPfZR8fGtikov',
#   'popularity': 55,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '5h1BN75CEh8wdSwE1xrbSe',
#   'song_name': 'Slow Dancing',
#   'duration_ms': 187026,
#   'url': 'https://open.spotify.com/track/5h1BN75CEh8wdSwE1xrbSe',
#   'popularity': 0,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '7ixOAT89NSsgUITYc5ByB5',
#   'artist_id': '3JsHnjpbhX4SnySpvpa9DK'},
#  {'song_id': '53dtP2iUMvaF28JZcHnFuU',
#   'song_name': 'logical',
#   'duration_ms': 231907,
#   'url': 'https://open.spotify.com/track/53dtP2iUMvaF28JZcHnFuU',
#   'popularity': 55,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '7ABLbnD53cQK00mhcaOUVG',
#   'song_name': 'LALA',
#   'duration_ms': 197920,
#   'url': 'https://open.spotify.com/track/7ABLbnD53cQK00mhcaOUVG',
#   'popularity': 99,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '3puAvurwvtvi1rodndIPW8',
#   'artist_id': '7iK8PXO48WeuP03g8YR51W'},
#  {'song_id': '5RqSsdzTNPX1uzkmlHCFvK',
#   'song_name': 'QLONA',
#   'duration_ms': 172797,
#   'url': 'https://open.spotify.com/track/5RqSsdzTNPX1uzkmlHCFvK',
#   'popularity': 90,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'artist_id': '790FomKkXshlbRYZFtlgla'},
#  {'song_id': '3Nl5OkkmS5DaBZvuYofpAt',
#   'song_name': 'the grudge',
#   'duration_ms': 189386,
#   'url': 'https://open.spotify.com/track/3Nl5OkkmS5DaBZvuYofpAt',
#   'popularity': 54,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '26QLJMK8G0M06sk7h7Fkse',
#   'song_name': 'love is embarrassing',
#   'duration_ms': 154516,
#   'url': 'https://open.spotify.com/track/26QLJMK8G0M06sk7h7Fkse',
#   'popularity': 54,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '1vYXt7VSjH9JIM5oRRo7vA',
#   'song_name': 'Dance The Night - From Barbie The Album',
#   'duration_ms': 176579,
#   'url': 'https://open.spotify.com/track/1vYXt7VSjH9JIM5oRRo7vA',
#   'popularity': 97,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '5cH7FqB7JD5q1tJXJ7FHYu',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we'},
#  {'song_id': '6XbtvPmIpyCbjuT0e8cQtp',
#   'song_name': 'Columbia',
#   'duration_ms': 186000,
#   'url': 'https://open.spotify.com/track/6XbtvPmIpyCbjuT0e8cQtp',
#   'popularity': 97,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '07kam1Dks7GIucbSelfvyX',
#   'artist_id': '52iwsT98xCoGgiGntTiR7K'},
#  {'song_id': '6W9l02gRsXVxzIuQC1oc1X',
#   'song_name': 'pretty isn’t pretty',
#   'duration_ms': 199422,
#   'url': 'https://open.spotify.com/track/6W9l02gRsXVxzIuQC1oc1X',
#   'popularity': 54,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '2N0SPREDYqILVEFSsWF5N5',
#   'song_name': 'Love Me Again',
#   'duration_ms': 182293,
#   'url': 'https://open.spotify.com/track/2N0SPREDYqILVEFSsWF5N5',
#   'popularity': 95,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1ZBDI1LqnuAKdrePUF2D5m',
#   'artist_id': '3JsHnjpbhX4SnySpvpa9DK'},
#  {'song_id': '6wf7Yu7cxBSPrRlWeSeK0Q',
#   'song_name': 'What Was I Made For? [From The Motion Picture "Barbie"]',
#   'duration_ms': 222369,
#   'url': 'https://open.spotify.com/track/6wf7Yu7cxBSPrRlWeSeK0Q',
#   'popularity': 98,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '3AafSrFIbJPH6BJHiJm1Cd',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '4rXLjWdF2ZZpXCVTfWcshS',
#   'song_name': 'fukumean',
#   'duration_ms': 125040,
#   'url': 'https://open.spotify.com/track/4rXLjWdF2ZZpXCVTfWcshS',
#   'popularity': 96,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '5qmZefgh78fN3jsyPPlvuw',
#   'artist_id': '2hlmm7s2ICUX0LVIhVFlZQ'},
#  {'song_id': '7fesNTgTEMEH0ye8MOgEDY',
#   'song_name': 'teenage dream',
#   'duration_ms': 222358,
#   'url': 'https://open.spotify.com/track/7fesNTgTEMEH0ye8MOgEDY',
#   'popularity': 53,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '5ydjxBSUIDn26MFzU3asP4',
#   'song_name': 'Rainy Days',
#   'duration_ms': 179560,
#   'url': 'https://open.spotify.com/track/5ydjxBSUIDn26MFzU3asP4',
#   'popularity': 93,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1ZBDI1LqnuAKdrePUF2D5m',
#   'artist_id': '3JsHnjpbhX4SnySpvpa9DK'},
#  {'song_id': '2FDTHlrBguDzQkp7PVj16Q',
#   'song_name': 'Sprinter',
#   'duration_ms': 229133,
#   'url': 'https://open.spotify.com/track/2FDTHlrBguDzQkp7PVj16Q',
#   'popularity': 96,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '5l0QlaI3wdZpE7ggoO5Rwg',
#   'artist_id': '6Ip8FS7vWT1uKkJSweANQK'},
#  {'song_id': '1odExI7RdWc4BT515LTAwj',
#   'song_name': 'Daylight',
#   'duration_ms': 212953,
#   'url': 'https://open.spotify.com/track/1odExI7RdWc4BT515LTAwj',
#   'popularity': 96,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '6NcI39WPu4kY6Tul11nhSv',
#   'artist_id': '33NVpKoXjItPwUJTMZIOiY'},
#  {'song_id': '4KULAymBBJcPRpk1yO4dOG',
#   'song_name': 'I Remember Everything (feat. Kacey Musgraves)',
#   'duration_ms': 227195,
#   'url': 'https://open.spotify.com/track/4KULAymBBJcPRpk1yO4dOG',
#   'popularity': 90,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '6PbnGueEO6LGodPfvNldYf',
#   'artist_id': '40ZNYROS4zLfyyBSs2PGe2'},
#  {'song_id': '4Dvkj6JhhA12EX05fT7y2e',
#   'song_name': 'As It Was',
#   'duration_ms': 167303,
#   'url': 'https://open.spotify.com/track/4Dvkj6JhhA12EX05fT7y2e',
#   'popularity': 91,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3'},
#  {'song_id': '7mXuWTczZNxG5EDcjFEuJR',
#   'song_name': 'LADY GAGA',
#   'duration_ms': 212878,
#   'url': 'https://open.spotify.com/track/7mXuWTczZNxG5EDcjFEuJR',
#   'popularity': 94,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '4jox3ip1I39DFC2B7R5qLH',
#   'artist_id': '12GqGscKJx3aE4t07u7eVZ'},
#  {'song_id': '4DHcnVTT87F0zZhRPYmZ3B',
#   'song_name': 'Flowers',
#   'duration_ms': 200600,
#   'url': 'https://open.spotify.com/track/4DHcnVTT87F0zZhRPYmZ3B',
#   'popularity': 95,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'artist_id': '5YGY8feqx7naU7z4HrwZM6'},
#  {'song_id': '59NraMJsLaMCVtwXTSia8i',
#   'song_name': 'Prada',
#   'duration_ms': 132359,
#   'url': 'https://open.spotify.com/track/59NraMJsLaMCVtwXTSia8i',
#   'popularity': 90,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '5MU0RmBSpoSxOPYBfcobDc',
#   'artist_id': '5wCmhq5J2hPwL2r0eKurxn'},
#  {'song_id': '1Qrg8KqiBpW07V7PNxwwwL',
#   'song_name': 'Kill Bill',
#   'duration_ms': 153946,
#   'url': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL',
#   'popularity': 92,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '6uIIdjYTxxpWOyWuVXrKQO',
#   'song_name': 'Que Onda',
#   'duration_ms': 191466,
#   'url': 'https://open.spotify.com/track/6uIIdjYTxxpWOyWuVXrKQO',
#   'popularity': 85,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '4x6cjOcVz44aiLSOHCLKPd',
#   'artist_id': '6dLuQ5qXxIuWc5urxfIiZR'},
#  {'song_id': '5XeFesFbtLpXzIVDNQP22n',
#   'song_name': 'I Wanna Be Yours',
#   'duration_ms': 183956,
#   'url': 'https://open.spotify.com/track/5XeFesFbtLpXzIVDNQP22n',
#   'popularity': 94,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '78bpIziExqiI9qztvNFlQu',
#   'artist_id': '7Ln80lUS6He07XvHI8qqHH'},
#  {'song_id': '6XSqqQIy7Lm7SnwxS4NrGx',
#   'song_name': 'Classy 101',
#   'duration_ms': 195986,
#   'url': 'https://open.spotify.com/track/6XSqqQIy7Lm7SnwxS4NrGx',
#   'popularity': 94,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '4jtQUtS4ABgER3DnGfKJCv',
#   'artist_id': '2LRoIwlKmHjgvigdNGBHNo'},
#  {'song_id': '5sdQOyqq2IDhvmx2lHOpwd',
#   'song_name': 'Super Shy',
#   'duration_ms': 154666,
#   'url': 'https://open.spotify.com/track/5sdQOyqq2IDhvmx2lHOpwd',
#   'popularity': 94,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '5V729UqvhwNOcMejx0m55I',
#   'artist_id': '6HvZYsbFfjnjFrWF950C9d'},
#  {'song_id': '23RoR84KodL5HWvUTneQ1w',
#   'song_name': '(It Goes Like) Nanana - Edit',
#   'duration_ms': 231545,
#   'url': 'https://open.spotify.com/track/23RoR84KodL5HWvUTneQ1w',
#   'popularity': 94,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '2LVDNOUUy2g8517ZEtQIcK',
#   'artist_id': '2mLA48B366zkELXYx7hcDN'},
#  {'song_id': '7ro0hRteUMfnOioTFI5TG1',
#   'song_name': 'WHERE SHE GOES',
#   'duration_ms': 231704,
#   'url': 'https://open.spotify.com/track/7ro0hRteUMfnOioTFI5TG1',
#   'popularity': 96,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '5gCcb5fsSb6w5K8SyJrgtB',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '741UUVE2kuITl0c6zuqqbO',
#   'song_name': 'Barbie World (with Aqua) [From Barbie The Album]',
#   'duration_ms': 109750,
#   'url': 'https://open.spotify.com/track/741UUVE2kuITl0c6zuqqbO',
#   'popularity': 94,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '5CM66hwjlbZ06LhONWXOAs',
#   'artist_id': '0hCNtLu0JehylgoiP8L4Gh'},
#  {'song_id': '2UW7JaomAMuX9pZrjVpHAU',
#   'song_name': 'La Bebe - Remix',
#   'duration_ms': 234352,
#   'url': 'https://open.spotify.com/track/2UW7JaomAMuX9pZrjVpHAU',
#   'popularity': 95,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'artist_id': '1NNRWkhwmcXRimFYSBpB1y'},
#  {'song_id': '25OeKzcqakFPaJlXHPE5lm',
#   'song_name': 'Primera Cita',
#   'duration_ms': 186455,
#   'url': 'https://open.spotify.com/track/25OeKzcqakFPaJlXHPE5lm',
#   'popularity': 85,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '52PtAAvfi8ZGTRK5c700y4',
#   'artist_id': '66ihevNkSYNzRAl44dx6jJ'},
#  {'song_id': '54zcJnb3tp9c5OVKREZ1Is',
#   'song_name': 'MI EX TENÍA RAZÓN',
#   'duration_ms': 154374,
#   'url': 'https://open.spotify.com/track/54zcJnb3tp9c5OVKREZ1Is',
#   'popularity': 87,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'artist_id': '790FomKkXshlbRYZFtlgla'},
#  {'song_id': '6WzRpISELf3YglGAh7TXcG',
#   'song_name': 'Popular (with Playboi Carti & Madonna) - Music from the HBO Original Series',
#   'duration_ms': 215466,
#   'url': 'https://open.spotify.com/track/6WzRpISELf3YglGAh7TXcG',
#   'popularity': 93,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '5O0zUvdnJr0RbWzLFneN2i',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '6irysuQyZWd7Bjj7ePiOs2',
#   'song_name': 'Holanda',
#   'duration_ms': 231693,
#   'url': 'https://open.spotify.com/track/6irysuQyZWd7Bjj7ePiOs2',
#   'popularity': 91,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '42D6fdFJ4SLnh4jXZJrsNa',
#   'artist_id': '6nVcHLIgY5pE2YCl8ubca1'},
#  {'song_id': '2UU11hvjN1JIn4iihEodNT',
#   'song_name': 'Blue',
#   'duration_ms': 149853,
#   'url': 'https://open.spotify.com/track/2UU11hvjN1JIn4iihEodNT',
#   'popularity': 0,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '7ixOAT89NSsgUITYc5ByB5',
#   'artist_id': '3JsHnjpbhX4SnySpvpa9DK'},
#  {'song_id': '6wsqVwoiVH2kde4k4KKAFU',
#   'song_name': 'I KNOW ?',
#   'duration_ms': 211582,
#   'url': 'https://open.spotify.com/track/6wsqVwoiVH2kde4k4KKAFU',
#   'popularity': 93,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'song_id': '4HAOgAnILvXCbSODMoRnmD',
#   'song_name': 'For Us',
#   'duration_ms': 171160,
#   'url': 'https://open.spotify.com/track/4HAOgAnILvXCbSODMoRnmD',
#   'popularity': 0,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '7ixOAT89NSsgUITYc5ByB5',
#   'artist_id': '3JsHnjpbhX4SnySpvpa9DK'},
#  {'song_id': '4lIxdJw6W3Fg4vUIYCB0S5',
#   'song_name': 'Style',
#   'duration_ms': 231000,
#   'url': 'https://open.spotify.com/track/4lIxdJw6W3Fg4vUIYCB0S5',
#   'popularity': 83,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '1p80LdxRV74UKvL8gnD7ky',
#   'song_name': 'Blank Space',
#   'duration_ms': 231826,
#   'url': 'https://open.spotify.com/track/1p80LdxRV74UKvL8gnD7ky',
#   'popularity': 83,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '5mjYQaktjmjcMKcUIcqz4s',
#   'song_name': 'Strangers',
#   'duration_ms': 172964,
#   'url': 'https://open.spotify.com/track/5mjYQaktjmjcMKcUIcqz4s',
#   'popularity': 83,
#   'song_added': '2023-09-09T11:16:37Z',
#   'album_id': '18ogtNq9F7DmMkNYO6Xb4k',
#   'artist_id': '7uMDnSZyUYNBPLhPMNuaM2'}]

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                 name release_date  total_tracks
# 0  54dZypaXHAIDzBe9ujAZ63   Paint The Town Red   2023-08-04             1  \
# 1  53985D8g3JcGBoULSOYYKX  Seven (feat. Latto)   2023-07-14             3
# 2  1xJHno7SmdVtZAtXbdbDZp                 GUTS   2023-09-08            12
# 3  1xJHno7SmdVtZAtXbdbDZp                 GUTS   2023-09-08            12
# 4  1xJHno7SmdVtZAtXbdbDZp                 GUTS   2023-09-08            12
#
#                                                  url
# 0  https://open.spotify.com/album/54dZypaXHAIDzBe...
# 1  https://open.spotify.com/album/53985D8g3JcGBoU...
# 2  https://open.spotify.com/album/1xJHno7SmdVtZAt...
# 3  https://open.spotify.com/album/1xJHno7SmdVtZAt...
# 4  https://open.spotify.com/album/1xJHno7SmdVtZAt...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset = ['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                 artist_id     artist_name
# 0  5cj0lLjcoR7YOSnhnX0Po5        Doja Cat  \
# 1  6HaGTQPmzraVmaVxvz6EUc       Jung Kook
# 2  3MdXrJWsbVzdn6fe5JYkSQ           Latto
# 3  1McMsnEElThX1knmY4oliG  Olivia Rodrigo
# 4  1McMsnEElThX1knmY4oliG  Olivia Rodrigo
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5cj0lLjcoR7...
# 1  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 2  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 3  https://api.spotify.com/v1/artists/1McMsnEElTh...
# 4  https://api.spotify.com/v1/artists/1McMsnEElTh...

# %%
artist_df = artist_df.drop_duplicates(subset = ['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id                            song_name  duration_ms
# 0  2IGMVunIBsBLtEQyoI1Mu7                   Paint The Town Red       231750  \
# 1  7x9aauaA9cu6tyfpHnqDLo  Seven (feat. Latto) (Explicit Ver.)       184400
# 2  1kuGVB7EU95pJObxwvfwKS                              vampire       219724
# 3  3IX0yuEVvDbnqUwMBB3ouC                      bad idea right?       184783
# 4  34sOdxWu9FljH84UXdRwu1                   all-american bitch       165833
#
#                                                  url  popularity
# 0  https://open.spotify.com/track/2IGMVunIBsBLtEQ...          98  \
# 1  https://open.spotify.com/track/7x9aauaA9cu6tyf...          99
# 2  https://open.spotify.com/track/1kuGVB7EU95pJOb...          50
# 3  https://open.spotify.com/track/3IX0yuEVvDbnqUw...          52
# 4  https://open.spotify.com/track/34sOdxWu9FljH84...          58
#
#              song_added                album_id               artist_id
# 0  2023-09-09T11:16:37Z  54dZypaXHAIDzBe9ujAZ63  5cj0lLjcoR7YOSnhnX0Po5
# 1  2023-09-09T11:16:37Z  53985D8g3JcGBoULSOYYKX  6HaGTQPmzraVmaVxvz6EUc
# 2  2023-09-09T11:16:37Z  1xJHno7SmdVtZAtXbdbDZp  1McMsnEElThX1knmY4oliG
# 3  2023-09-09T11:16:37Z  1xJHno7SmdVtZAtXbdbDZp  1McMsnEElThX1knmY4oliG
# 4  2023-09-09T11:16:37Z  1xJHno7SmdVtZAtXbdbDZp  1McMsnEElThX1knmY4oliG

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name
# 0  5cj0lLjcoR7YOSnhnX0Po5        Doja Cat  \
# 1  6HaGTQPmzraVmaVxvz6EUc       Jung Kook
# 2  3MdXrJWsbVzdn6fe5JYkSQ           Latto
# 3  1McMsnEElThX1knmY4oliG  Olivia Rodrigo
# 4  1McMsnEElThX1knmY4oliG  Olivia Rodrigo
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5cj0lLjcoR7...
# 1  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 2  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 3  https://api.spotify.com/v1/artists/1McMsnEElTh...
# 4  https://api.spotify.com/v1/artists/1McMsnEElTh...

# %%
album_df.head()
# Out:
#                   album_id                 name release_date  total_tracks
# 0   54dZypaXHAIDzBe9ujAZ63   Paint The Town Red   2023-08-04             1  \
# 1   53985D8g3JcGBoULSOYYKX  Seven (feat. Latto)   2023-07-14             3
# 2   1xJHno7SmdVtZAtXbdbDZp                 GUTS   2023-09-08            12
# 6   1NAmidJlEaVgA3MpcPFYGq                Lover   2019-08-23            18
# 10  7ixOAT89NSsgUITYc5ByB5              Layover   2023-09-08             6
#
#                                                   url
# 0   https://open.spotify.com/album/54dZypaXHAIDzBe...
# 1   https://open.spotify.com/album/53985D8g3JcGBoU...
# 2   https://open.spotify.com/album/1xJHno7SmdVtZAt...
# 6   https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 10  https://open.spotify.com/album/7ixOAT89NSsgUIT...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\mohds\AppData\Local\Temp\ipykernel_16524\3126744046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      34 non-null     object
#  1   name          34 non-null     object
#  2   release_date  34 non-null     datetime64[ns]
#  3   total_tracks  34 non-null     int64
#  4   url           34 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df
# Out:
#                    song_id                                          song_name
# 0   2IGMVunIBsBLtEQyoI1Mu7                                 Paint The Town Red  \
# 1   7x9aauaA9cu6tyfpHnqDLo                Seven (feat. Latto) (Explicit Ver.)
# 2   1kuGVB7EU95pJObxwvfwKS                                            vampire
# 3   3IX0yuEVvDbnqUwMBB3ouC                                    bad idea right?
# 4   34sOdxWu9FljH84UXdRwu1                                 all-american bitch
# 5   2gyxAWHebV7xPYVxqoi86f                                      get him back!
# 6   1BxfuPKGuaTgP7aM0Bbdwr                                       Cruel Summer
# 7   6QT6j7rKt7Vk3IuV2AUO9W                                               lacy
# 8   5sp71CUt0jXRNqHblPGp7b                      ballad of a homeschooled girl
# 9   5CscrLqFBgPfZR8fGtikov                                     making the bed
# 10  5h1BN75CEh8wdSwE1xrbSe                                       Slow Dancing
# 11  53dtP2iUMvaF28JZcHnFuU                                            logical
# 12  7ABLbnD53cQK00mhcaOUVG                                               LALA
# 13  5RqSsdzTNPX1uzkmlHCFvK                                              QLONA
# 14  3Nl5OkkmS5DaBZvuYofpAt                                         the grudge
# 15  26QLJMK8G0M06sk7h7Fkse                               love is embarrassing
# 16  1vYXt7VSjH9JIM5oRRo7vA            Dance The Night - From Barbie The Album
# 17  6XbtvPmIpyCbjuT0e8cQtp                                           Columbia
# 18  6W9l02gRsXVxzIuQC1oc1X                                pretty isn’t pretty
# 19  2N0SPREDYqILVEFSsWF5N5                                      Love Me Again
# 20  6wf7Yu7cxBSPrRlWeSeK0Q  What Was I Made For? [From The Motion Picture ...
# 21  4rXLjWdF2ZZpXCVTfWcshS                                           fukumean
# 22  7fesNTgTEMEH0ye8MOgEDY                                      teenage dream
# 23  5ydjxBSUIDn26MFzU3asP4                                         Rainy Days
# 24  2FDTHlrBguDzQkp7PVj16Q                                           Sprinter
# 25  1odExI7RdWc4BT515LTAwj                                           Daylight
# 26  4KULAymBBJcPRpk1yO4dOG      I Remember Everything (feat. Kacey Musgraves)
# 27  4Dvkj6JhhA12EX05fT7y2e                                          As It Was
# 28  7mXuWTczZNxG5EDcjFEuJR                                          LADY GAGA
# 29  4DHcnVTT87F0zZhRPYmZ3B                                            Flowers
# 30  59NraMJsLaMCVtwXTSia8i                                              Prada
# 31  1Qrg8KqiBpW07V7PNxwwwL                                          Kill Bill
# 32  6uIIdjYTxxpWOyWuVXrKQO                                           Que Onda
# 33  5XeFesFbtLpXzIVDNQP22n                                   I Wanna Be Yours
# 34  6XSqqQIy7Lm7SnwxS4NrGx                                         Classy 101
# 35  5sdQOyqq2IDhvmx2lHOpwd                                          Super Shy
# 36  23RoR84KodL5HWvUTneQ1w                       (It Goes Like) Nanana - Edit
# 37  7ro0hRteUMfnOioTFI5TG1                                     WHERE SHE GOES
# 38  741UUVE2kuITl0c6zuqqbO   Barbie World (with Aqua) [From Barbie The Album]
# 39  2UW7JaomAMuX9pZrjVpHAU                                    La Bebe - Remix
# 40  25OeKzcqakFPaJlXHPE5lm                                       Primera Cita
# 41  54zcJnb3tp9c5OVKREZ1Is                                  MI EX TENÍA RAZÓN
# 42  6WzRpISELf3YglGAh7TXcG  Popular (with Playboi Carti & Madonna) - Music...
# 43  6irysuQyZWd7Bjj7ePiOs2                                            Holanda
# 44  2UU11hvjN1JIn4iihEodNT                                               Blue
# 45  6wsqVwoiVH2kde4k4KKAFU                                           I KNOW ?
# 46  4HAOgAnILvXCbSODMoRnmD                                             For Us
# 47  4lIxdJw6W3Fg4vUIYCB0S5                                              Style
# 48  1p80LdxRV74UKvL8gnD7ky                                        Blank Space
# 49  5mjYQaktjmjcMKcUIcqz4s                                          Strangers
#
#     duration_ms                                                url
# 0        231750  https://open.spotify.com/track/2IGMVunIBsBLtEQ...  \
# 1        184400  https://open.spotify.com/track/7x9aauaA9cu6tyf...
# 2        219724  https://open.spotify.com/track/1kuGVB7EU95pJOb...
# 3        184783  https://open.spotify.com/track/3IX0yuEVvDbnqUw...
# 4        165833  https://open.spotify.com/track/34sOdxWu9FljH84...
# 5        211141  https://open.spotify.com/track/2gyxAWHebV7xPYV...
# 6        178426  https://open.spotify.com/track/1BxfuPKGuaTgP7a...
# 7        177212  https://open.spotify.com/track/6QT6j7rKt7Vk3Iu...
# 8        203369  https://open.spotify.com/track/5sp71CUt0jXRNqH...
# 9        198866  https://open.spotify.com/track/5CscrLqFBgPfZR8...
# 10       187026  https://open.spotify.com/track/5h1BN75CEh8wdSw...
# 11       231907  https://open.spotify.com/track/53dtP2iUMvaF28J...
# 12       197920  https://open.spotify.com/track/7ABLbnD53cQK00m...
# 13       172797  https://open.spotify.com/track/5RqSsdzTNPX1uzk...
# 14       189386  https://open.spotify.com/track/3Nl5OkkmS5DaBZv...
# 15       154516  https://open.spotify.com/track/26QLJMK8G0M06sk...
# 16       176579  https://open.spotify.com/track/1vYXt7VSjH9JIM5...
# 17       186000  https://open.spotify.com/track/6XbtvPmIpyCbjuT...
# 18       199422  https://open.spotify.com/track/6W9l02gRsXVxzIu...
# 19       182293  https://open.spotify.com/track/2N0SPREDYqILVEF...
# 20       222369  https://open.spotify.com/track/6wf7Yu7cxBSPrRl...
# 21       125040  https://open.spotify.com/track/4rXLjWdF2ZZpXCV...
# 22       222358  https://open.spotify.com/track/7fesNTgTEMEH0ye...
# 23       179560  https://open.spotify.com/track/5ydjxBSUIDn26MF...
# 24       229133  https://open.spotify.com/track/2FDTHlrBguDzQkp...
# 25       212953  https://open.spotify.com/track/1odExI7RdWc4BT5...
# 26       227195  https://open.spotify.com/track/4KULAymBBJcPRpk...
# 27       167303  https://open.spotify.com/track/4Dvkj6JhhA12EX0...
# 28       212878  https://open.spotify.com/track/7mXuWTczZNxG5ED...
# 29       200600  https://open.spotify.com/track/4DHcnVTT87F0zZh...
# 30       132359  https://open.spotify.com/track/59NraMJsLaMCVtw...
# 31       153946  https://open.spotify.com/track/1Qrg8KqiBpW07V7...
# 32       191466  https://open.spotify.com/track/6uIIdjYTxxpWOyW...
# 33       183956  https://open.spotify.com/track/5XeFesFbtLpXzIV...
# 34       195986  https://open.spotify.com/track/6XSqqQIy7Lm7Snw...
# 35       154666  https://open.spotify.com/track/5sdQOyqq2IDhvmx...
# 36       231545  https://open.spotify.com/track/23RoR84KodL5HWv...
# 37       231704  https://open.spotify.com/track/7ro0hRteUMfnOio...
# 38       109750  https://open.spotify.com/track/741UUVE2kuITl0c...
# 39       234352  https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 40       186455  https://open.spotify.com/track/25OeKzcqakFPaJl...
# 41       154374  https://open.spotify.com/track/54zcJnb3tp9c5OV...
# 42       215466  https://open.spotify.com/track/6WzRpISELf3YglG...
# 43       231693  https://open.spotify.com/track/6irysuQyZWd7Bjj...
# 44       149853  https://open.spotify.com/track/2UU11hvjN1JIn4i...
# 45       211582  https://open.spotify.com/track/6wsqVwoiVH2kde4...
# 46       171160  https://open.spotify.com/track/4HAOgAnILvXCbSO...
# 47       231000  https://open.spotify.com/track/4lIxdJw6W3Fg4vU...
# 48       231826  https://open.spotify.com/track/1p80LdxRV74UKvL...
# 49       172964  https://open.spotify.com/track/5mjYQaktjmjcMKc...
#
#     popularity                song_added                album_id
# 0           98 2023-09-09 11:16:37+00:00  54dZypaXHAIDzBe9ujAZ63  \
# 1           99 2023-09-09 11:16:37+00:00  53985D8g3JcGBoULSOYYKX
# 2           50 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 3           52 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 4           58 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 5           56 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 6          100 2023-09-09 11:16:37+00:00  1NAmidJlEaVgA3MpcPFYGq
# 7           56 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 8           56 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 9           55 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 10           0 2023-09-09 11:16:37+00:00  7ixOAT89NSsgUITYc5ByB5
# 11          55 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 12          99 2023-09-09 11:16:37+00:00  3puAvurwvtvi1rodndIPW8
# 13          90 2023-09-09 11:16:37+00:00  0FqAaUEyKCyUNFE1uQPZ7i
# 14          54 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 15          54 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 16          97 2023-09-09 11:16:37+00:00  5cH7FqB7JD5q1tJXJ7FHYu
# 17          97 2023-09-09 11:16:37+00:00  07kam1Dks7GIucbSelfvyX
# 18          54 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 19          95 2023-09-09 11:16:37+00:00  1ZBDI1LqnuAKdrePUF2D5m
# 20          98 2023-09-09 11:16:37+00:00  3AafSrFIbJPH6BJHiJm1Cd
# 21          96 2023-09-09 11:16:37+00:00  5qmZefgh78fN3jsyPPlvuw
# 22          53 2023-09-09 11:16:37+00:00  1xJHno7SmdVtZAtXbdbDZp
# 23          93 2023-09-09 11:16:37+00:00  1ZBDI1LqnuAKdrePUF2D5m
# 24          96 2023-09-09 11:16:37+00:00  5l0QlaI3wdZpE7ggoO5Rwg
# 25          96 2023-09-09 11:16:37+00:00  6NcI39WPu4kY6Tul11nhSv
# 26          90 2023-09-09 11:16:37+00:00  6PbnGueEO6LGodPfvNldYf
# 27          91 2023-09-09 11:16:37+00:00  5r36AJ6VOJtp00oxSkBZ5h
# 28          94 2023-09-09 11:16:37+00:00  4jox3ip1I39DFC2B7R5qLH
# 29          95 2023-09-09 11:16:37+00:00  0HiZ8fNXwJOQcrf5iflrdz
# 30          90 2023-09-09 11:16:37+00:00  5MU0RmBSpoSxOPYBfcobDc
# 31          92 2023-09-09 11:16:37+00:00  1nrVofqDRs7cpWXJ49qTnP
# 32          85 2023-09-09 11:16:37+00:00  4x6cjOcVz44aiLSOHCLKPd
# 33          94 2023-09-09 11:16:37+00:00  78bpIziExqiI9qztvNFlQu
# 34          94 2023-09-09 11:16:37+00:00  4jtQUtS4ABgER3DnGfKJCv
# 35          94 2023-09-09 11:16:37+00:00  5V729UqvhwNOcMejx0m55I
# 36          94 2023-09-09 11:16:37+00:00  2LVDNOUUy2g8517ZEtQIcK
# 37          96 2023-09-09 11:16:37+00:00  5gCcb5fsSb6w5K8SyJrgtB
# 38          94 2023-09-09 11:16:37+00:00  5CM66hwjlbZ06LhONWXOAs
# 39          95 2023-09-09 11:16:37+00:00  6aBVGuOUEuX18rHxyDWbti
# 40          85 2023-09-09 11:16:37+00:00  52PtAAvfi8ZGTRK5c700y4
# 41          87 2023-09-09 11:16:37+00:00  0FqAaUEyKCyUNFE1uQPZ7i
# 42          93 2023-09-09 11:16:37+00:00  5O0zUvdnJr0RbWzLFneN2i
# 43          91 2023-09-09 11:16:37+00:00  42D6fdFJ4SLnh4jXZJrsNa
# 44           0 2023-09-09 11:16:37+00:00  7ixOAT89NSsgUITYc5ByB5
# 45          93 2023-09-09 11:16:37+00:00  18NOKLkZETa4sWwLMIm0UZ
# 46           0 2023-09-09 11:16:37+00:00  7ixOAT89NSsgUITYc5ByB5
# 47          83 2023-09-09 11:16:37+00:00  2QJmrSgbdM35R67eoGQo4j
# 48          83 2023-09-09 11:16:37+00:00  2QJmrSgbdM35R67eoGQo4j
# 49          83 2023-09-09 11:16:37+00:00  18ogtNq9F7DmMkNYO6Xb4k
#
#                  artist_id
# 0   5cj0lLjcoR7YOSnhnX0Po5
# 1   6HaGTQPmzraVmaVxvz6EUc
# 2   1McMsnEElThX1knmY4oliG
# 3   1McMsnEElThX1knmY4oliG
# 4   1McMsnEElThX1knmY4oliG
# 5   1McMsnEElThX1knmY4oliG
# 6   06HL4z0CvFAxyc27GXpf02
# 7   1McMsnEElThX1knmY4oliG
# 8   1McMsnEElThX1knmY4oliG
# 9   1McMsnEElThX1knmY4oliG
# 10  3JsHnjpbhX4SnySpvpa9DK
# 11  1McMsnEElThX1knmY4oliG
# 12  7iK8PXO48WeuP03g8YR51W
# 13  790FomKkXshlbRYZFtlgla
# 14  1McMsnEElThX1knmY4oliG
# 15  1McMsnEElThX1knmY4oliG
# 16  6M2wZ9GZgrQXHCFfjv46we
# 17  52iwsT98xCoGgiGntTiR7K
# 18  1McMsnEElThX1knmY4oliG
# 19  3JsHnjpbhX4SnySpvpa9DK
# 20  6qqNVTkY8uBg9cP3Jd7DAH
# 21  2hlmm7s2ICUX0LVIhVFlZQ
# 22  1McMsnEElThX1knmY4oliG
# 23  3JsHnjpbhX4SnySpvpa9DK
# 24  6Ip8FS7vWT1uKkJSweANQK
# 25  33NVpKoXjItPwUJTMZIOiY
# 26  40ZNYROS4zLfyyBSs2PGe2
# 27  6KImCVD70vtIoJWnq6nGn3
# 28  12GqGscKJx3aE4t07u7eVZ
# 29  5YGY8feqx7naU7z4HrwZM6
# 30  5wCmhq5J2hPwL2r0eKurxn
# 31  7tYKF4w9nC0nq9CsPZTHyP
# 32  6dLuQ5qXxIuWc5urxfIiZR
# 33  7Ln80lUS6He07XvHI8qqHH
# 34  2LRoIwlKmHjgvigdNGBHNo
# 35  6HvZYsbFfjnjFrWF950C9d
# 36  2mLA48B366zkELXYx7hcDN
# 37  4q3ewBCX7sLwd24euuV69X
# 38  0hCNtLu0JehylgoiP8L4Gh
# 39  1NNRWkhwmcXRimFYSBpB1y
# 40  66ihevNkSYNzRAl44dx6jJ
# 41  790FomKkXshlbRYZFtlgla
# 42  1Xyo4u8uXC1ZmMpatF05PJ
# 43  6nVcHLIgY5pE2YCl8ubca1
# 44  3JsHnjpbhX4SnySpvpa9DK
# 45  0Y5tJX1MQlPlqiwlOH1tJY
# 46  3JsHnjpbhX4SnySpvpa9DK
# 47  06HL4z0CvFAxyc27GXpf02
# 48  06HL4z0CvFAxyc27GXpf02
# 49  7uMDnSZyUYNBPLhPMNuaM2
